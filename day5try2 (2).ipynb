# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/08/06/outsmart/',
#  'https://edwarddonner.com/2024/08/06/outsmart/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/08/06/outsmart/
# https://edwarddonner.com/2024/08/06/outsmart/
# https://edwarddonner.com/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest â ‹ pulling manifest â ™ pulling manifest â ¹ pulling manifest â ¸ pulling manifest â ¼ pulling manifest â ´ pulling manifest â ¦ pulling manifest â § pulling manifest â ‡ pulling manifest â � pulling manifest â ‹ pulling manifest â ™ pulling manifest
# pulling dde5aa3fc5ff... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 2.0 GB
# pulling 966de95ca8a6... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 1.4 KB
# pulling fcc5a6bec9da... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 7.7 KB
# pulling a70ff7e570d9... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 6.0 KB
# pulling 56bb8bd477a5... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�   96 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 2.0 GB
# pulling 966de95ca8a6... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 1.4 KB
# pulling fcc5a6bec9da... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 7.7 KB
# pulling a70ff7e570d9... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 6.0 KB
# pulling 56bb8bd477a5... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�   96 B
# pulling 34bb5ab01051... 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %%
def get_links(url):
    website = Website(url)
    response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
Symphonize = Website("https://www.symphonize.com/")
Symphonize.links
# Out:
# ['/',
#  '/about',
#  '/services',
#  'https://www.symphonize.com/case-studies',
#  '/insights',
#  '/careers',
#  '/contact-us',
#  '/contact-us',
#  '/services',
#  '/contact-us',
#  '/services',
#  '/services-page#web-mobile-development',
#  '/services-page#ui-ux-design',
#  '/services-page#360-cloud-services',
#  '/services-page#intelligent-process-automation',
#  '/services-page#web-mobile-development',
#  '/services-page#ui-ux-design',
#  '/services-page#360-cloud-services',
#  '/services-page#intelligent-process-automation',
#  '/website-ver3/services-page#ui-ux-design',
#  '/website-ver3/services-page#web-mobile-development',
#  '/website-ver3/services-page#360-cloud-services',
#  '/website-ver3/services-page#intelligent-process-automation',
#  '/contact-us',
#  '/contact-us',
#  '#top-hero-section',
#  '/privacy-policy',
#  'https://twitter.com/i/flow/login?redirect_after_login=%2FSymphonizeInc',
#  'https://www.facebook.com/SymphonizeInc/',
#  'https://www.linkedin.com/company/symphonizeinc/',
#  'https://twitter.com/i/flow/login?redirect_after_login=%2FSymphonizeInc',
#  'https://www.facebook.com/SymphonizeInc/',
#  'https://www.linkedin.com/company/symphonizeinc/',
#  '/privacy-policy']

# %%
get_links("https://www.symphonize.com/")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://www.symphonize.com/about'},
#   {'type': 'case studies page',
#    'url': 'https://www.symphonize.com/case-studies'},
#   {'type': 'insights page', 'url': 'https://www.symphonize.com/insights'},
#   {'type': 'careers page', 'url': 'https://www.symphonize.com/careers'},
#   {'type': 'contact us link', 'url': 'https://www.symphonize.com/contact-us'}]}

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://www.symphonize.com/"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://www.symphonize.com/about'}, {'type': 'case studies page', 'url': 'https://www.symphonize.com/case-studies'}, {'type': 'insights page', 'url': 'https://www.symphonize.com/insights'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/symphonizeinc/'}, {'type': 'careers page', 'url': 'https://www.symphonize.com/careers'}]}
# Landing page:
# Webpage Title:
# Symphonize | Amplify your digital transformation.
# Webpage Contents:
# About Us
# Services
# Case Studies
# Insights
# Careers
# Contact
# Contact
# Amplify your digital transformation.
# Our team of experts in UX, Engineering, and Delivery collaborates seamlessly to craft innovative solutions that maximize results.
# Data-Driven, Cloud-Centric, & User-Focused solutions that resonate.
# Symphonize is a renowned partner skilled in strategy, user experience design, and software development. Trusted globally, with expertise spanning business process automation to mobile and web-based applications, we work with clients across various industries, from startups to multinational corporations.
# Learn More
# The challenge of conducting digital transformation.
# Digital transformation poses a major challenge for many organizations, primarily due to the absence of a skilled team. At Symphonize, we harmonize the strengths of enterprise architecture, development, insightful business acumen, and thoughtful UX design. This allows us to assemble the right team for your digital transformation journey, realizing tangible impact and measurable results.
# Contact
# We have the expertise to meet your specific needs and orchestrate your successful digital transformation.
# Learn More
# We fuse technical excellence with a strategic mindset, creating results that resonate with today’s dynamic business landscape.
# Web and Mobile Development
# Our skilled engineers combine the latest technology stack with hassle-free deployment, ensuring your digital presence is impactful and effective.
# User Interface/User Experience Design
# Our design experts craft a seamless customer journey that provides thoughtful guidance and minimizes friction.
# Ongoing Support
# We provide end-to-end cloud services, including strategy, architecture, migration, and perpetual optimization, ensuring your business operates efficiently and securely.
# Continuous Evolution
# Symphonize specializes in automating workflows to take advantage of the latest AI capabilities, allowing you to focus on innovation and growth while we maximize operational efficiency.
# Our services
# Web and Mobile Development
# Our skilled engineers combine the latest technology stack with hassle-free deployment, ensuring your digital presence is impactful and effective.
# Learn More
# User Interface/User Experience Design
# Our design experts craft a seamless customer journey that provides thoughtful guidance and minimizes friction.
# Learn More
# Cloud Services
# We provide end-to-end cloud services, including strategy, architecture, migration, and perpetual optimization, ensuring your business operates efficiently and securely.
# Learn More
# Intelligent Process Automation
# Symphonize specializes in automating workflows to take advantage of the latest AI capabilities, allowing you to focus on innovation and growth while we maximize operational efficiency.
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Web and Mobile Development
# Our skilled engineers combine the latest technology stack with hassle-free deployment, ensuring your digital presence is impactful and effective.
# Learn More
# UI / UX Design
# Our design experts craft a seamless customer journey that provides thoughtful guidance and minimizes friction.
# Learn More
# Cloud Services
# We provide end-to-end cloud services, including strategy, architecture, migration and optimization, ensuring your business operates efficiently.
# Learn More
# Intelligent Process Automation
# We specialize in automating workflows to take advantage of the latest AI capabilities, allowing you to focus on business growth while maximizing efficiency.
# Learn More
# Our services
# UX / UI design and development
# Our design experts craft a seamless customer journey that provides thoughtful guidance and minimizes friction.
# Learn More
# Web and Mobile Development
# Our skilled engineers combine the latest technology stack with hassle-free deployment, ensuring your digital presence is impactful and effective.
# Learn More
# Cloud Services
# We provide end-to-end cloud services, including strategy, architecture, migration, and perpetual optimization, ensuring your business operates efficiently and securely.
# Learn More
# Intelligent Process Automation
# Symphonize specializes in automating workflows to take advantage of the latest AI capabilities, allowing you to focus on innovation and growth while we maximize operational efficiency.
# Learn More
# Strategy
# Data-Driven
# Design
# User-Focused
# Development
# Cloud-Centric
# We harmonize design thinking with technical excellence.
# Let us guide you through the modern landscape with an optimized delivery model, unbeatable value, and unwavering integrity. Allow our team of experts in UX, Engineering, and Delivery to create your next digital eperience that resonates with your customers, and amplifies your
# transformation journey.
# Contact
# We deliver solutions to:
# Patricia Campbell, Chief Operating Officer.
# Christian Financial Credit Union
# "The Symphonize team is amazing! Their ideas and designs for our website are truly exceptional, and they consistently follow through on delivery. With their flexible, collaborative approach, they are a pleasure to work with, and we just love the end result."
# Sean Johnston, Senior Vice President - Operations and Technology.
# Huntington National Bank
# "The Symphonize team makes it so much easier! They can see through the complexity and the outliers to pull together an elegant solution that makes a complex product more intuitive. The team is always great to work with, challenging us when needed and helping us see beyond our requirements. We’ve been thrilled with the results so far and look forward to what the future will bring."
# Ed Rose, CEO.
# Paqqets
# "Symphonize brings the expertise we need to make good decisions and stay calibrated. Our teams work together seamlessly. If you sat in on a working session, it would be hard to tell the Symphonize folks from my team. They have a seat at the table for every important decision."
# David Jones, CIO.
# Meridian Medical Management
# "Symphonize is a one-stop shop that supports us at every stage: from whiteboarding to architecture to development to implementation. They know what the market is doing and reliably guide us to next generation technologies that will put us ahead of our competition."
# Fady Zoweil, VP of Professional Services.
# Thales Group
# "The Symphonize Solution Architects and development team are excellent. We can assign tough tasks and know they will do them right without creating complexity or delays. I trust Symphonize to deliver on our commitment and achieve our customer’s goals because they've been doing it for 8 years now."
# Terry Leahy, CEO.
# Meridian Medical Management
# "We have been successfully partnering with Symphonize for many years on a broad variety of technologies and product roadmaps. From Big Data analytics product development to rapid development and deployment of RPA,
# Symphonize has been our key strategic relationship.
# Their team functions seamlessly as an extension of our product management teams, which has enabled us to dramatically increase release velocity and quality simultaneously."
# Our unified teams harmonise design thinking and technical excellence to chart new digital experiences.
# Let us orchestrate your digital transformation with unmatched expertise and integrity.
# BOOK A FREE CONSULT
# Connect with us
# California
# 920 Reserve Dr
# Ste 100
# Roseville, CA 95678
# Michigan
# 3051 Miller Rd
# Ann Arbor, MI 48103
# Bengaluru
# Beech E-1, Manyata
# Embassy Business Park
# Ground Floor
# Outer Ring Road, Nagawara
# KA - 560045
# Hyderabad
# 3rd Floor, Plot No. 14/2
# Sector-1, HUDA Techno
# Enclave, Madhapur
# TS - 500081
# Vijayawada
# 3rd Floor
# Sai Odessey Complex
# NH16 Service Road
# Gurunanak Colony
# AP - 520008
# ©
# Symphonize, Inc. All rights reserved.
# | Privacy Policy
# ©
# Symphonize, Inc. All rights reserved.
# | Privacy Policy
# © 2016-2023 Symphonize, Inc. All rights reserved. | Privacy Policy.
#
#
#
# about page
# Webpage Title:
# About | Symphonize
# Webpage Contents:
# About Us
# Services
# Case Studies
# Insights
# Careers
# Contact
# Contact
# About us
# Our Values: In harmony with excellence
# At Symphonize, our values are the guiding principles that set the tone for your journey. We orchestrate every action with integrity, innovation, and commitment, creating the trust and excellence that resonates with our team, partners, and clients alike.
# Our core principles that define us and drive us to elevate your expectations:
# Client Obsession
# CEO Mindset
# Insist on Excellence
# Bias for Action
# Build Trust
# Fixate On Results
# Client Obsession
# We relentlessly pursue client success, aiming not just to satisfy but to delight. We bravely challenge assumptions because it’s the only way to achieve our clients’ goals.
# CEO Mindset
# We are all leaders, regardless of title. We show extreme ownership over everything we touch and never say, “That’s not my job.”
# Insist On Excellence
# We recognize that quality is a shared responsibility. We hold each other to the highest standards and work together to continuously raise the bar.
# Bias For Action
# We are go-getters. We embrace calculated risks because we know that, to innovate, we must step into the unknown. We believe trying and failing is better than not trying at all.
# Build Trust
# We are dependable, consistent, and candid. We speak our truth, listen attentively while others speak theirs, and then find a way forward together.
# Fixate On Results
# Setbacks are inevitable, but we never hide behind excuses. We rise to the occasion and find a way to deliver quality results, on time.
# Our core principles that define us and drive us to elevate your expectations:
# Client Obsession
# We relentlessly pursue client success, aiming not just to satisfy but to delight. We bravely challenge assumptions because it’s the only way to achieve our clients’ goals.
# CEO Mindset
# We are all leaders, regardless of title. We show extreme ownership over everything we touch and never say, “That’s not my job.”
# Bias For Action
# We are go-getters. We embrace calculated risks because we know that, to innovate, we must step into the unknown. We believe trying and failing is better than not trying at all.
# Insist On Excellence
# We recognize that quality is a shared responsibility. We hold each other to the highest standards and work together to continuously raise the bar.
# Build Trust
# We are dependable, consistent, and candid. We speak our truth, listen attentively while others speak theirs, and then find a way forward together.
# Fixate On Results
# Setbacks are inevitable, but we never hide behind excuses. We rise to the occasion and find a way to deliver quality results, on time.
# Key Team Members
# Ashok Cherukuri
# Co-Founder & CEO
# Sridhar Tirumala
# Co-Founder & CTO
# Sreedhar Tatavarthi
# VP of Software Solutions
# Chris Myers
# VP of Cloud Development
# Kyle Feliks
# VP of Creative Services
# Ryan Levin
# Director of Engineering
# Christopher Bibbs
# Director of Customer Success
# Emily Butler
# Client Engagement Manager
# Ray Sewell
# Solution Architect
# Our Corporate DNA
# Sacramento
# Chicago
# Ann Arbor
# Hyderabad
# Vijayawada
# Bengaluru
# Locations
# 5
# Founded
# 2012
# Team
# 170+
# Clients
# 60+
# Ann Arbor
# Chicago
# Sacramento
# Hyderabad
# Vijayawada
# Bengaluru
# "I get to work with all different types of people and teams. I’m constantly learning new things and upskilling my career.”
# Yogitha Karangula
# Project Lead
# "My favorite part of the project is collaborating with the engineering team to turn my design vision into a fully realized product."
# Charlie Szczygiel
# UX Designer
# Elevate Your Career with Symphonize
# At Symphonize, we’re not just building a company; we’re creating a movement. Our dedication to every client’s success, and our unwavering commitment to trust and personal responsibility in all our relationships, set us apart. If you’re passionate about making a meaningful impact while sharing our values, explore career opportunities at Symphonize today.
# View Open Positions
# We deliver solutions to:
# Patricia Campbell, Chief Operating Officer.
# Christian Financial Credit Union
# "The Symphonize team is amazing! Their ideas and designs for our website are truly exceptional, and they consistently follow through on delivery. With their flexible, collaborative approach, they are a pleasure to work with, and we just love the end result."
# Sean Johnston, Senior Vice President - Operations and Technology.
# Huntington National Bank
# "The Symphonize team makes it so much easier! They can see through the complexity and the outliers to pull together an elegant solution that makes a complex product more intuitive. The team is always great to work with, challenging us when needed and helping us see beyond our requirements. We’ve been thrilled with the results so far and look forward to what the future will bring."
# Ed Rose, CEO.
# Paqqets
# "Symphonize brings the expertise we need to make good decisions and stay calibrated. Our teams work together seamlessly. If you sat in on a working session, it would be hard to tell the Symphonize folks from my team. They have a seat at the table for every important decision."
# David Jones, CIO.
# Meridian Medical Management
# "Symphonize is a one-stop shop that supports us at every stage: from whiteboarding to architecture to development to implementation. They know what the market is doing and reliably guide us to next generation technologies that will put us ahead of our competition."
# Fady Zoweil, VP of Professional Services.
# Thales Group
# "The Symphonize Solution Architects and development team are excellent. We can assign tough tasks and know they will do them right without creating complexity or delays. I trust Symphonize to deliver on our commitment and achieve our customer’s goals because they've been doing it for 8 years now."
# Terry Leahy, CEO.
# Meridian Medical Management
# "We have been successfully partnering with Symphonize for many years on a broad variety of technologies and product roadmaps. From Big Data analytics product development to rapid development and deployment of RPA,
# Symphonize has been our key strategic relationship.
# Their team functions seamlessly as an extension of our product management teams, which has enabled us to dramatically increase release velocity and quality simultaneously."
# Our unified teams harmonise design thinking and technical excellence to chart new digital experiences.
# Let us orchestrate your digital transformation with unmatched expertise and integrity.
# BOOK A FREE CONSULT
# Connect with us
# California
# 920 Reserve Dr
# Ste 100
# Roseville, CA 95678
# Michigan
# 3051 Miller Rd
# Ann Arbor, MI 48103
# Bengaluru
# Beech E-1, Manyata
# Embassy Business Park
# Ground Floor
# Outer Ring Road, Nagawara
# KA - 560045
# Hyderabad
# 3rd Floor, Plot No. 14/2
# Sector-1, HUDA Techno
# Enclave, Madhapur
# TS - 500081
# Vijayawada
# 3rd Floor
# Sai Odessey Complex
# NH16 Service Road
# Gurunanak Colony
# AP - 520008
# ©
# Symphonize, Inc. All rights reserved.
# | Privacy Policy
# ©
# Symphonize, Inc. All rights reserved.
# | Privacy Policy
# © 2016-2023 Symphonize, Inc. All rights reserved. | Privacy Policy.
#
#
#
# case studies page
# Webpage Title:
# Case Studies | Symphonize
# Webpage Contents:
# About Us
# Services
# Case Studies
# Insights
# Careers
# Contact
# Contact
# Case Studies
# Data-driven, Cloud-centric, and User-focused Solutions
# At Symphonize, we orchestrate digital experiences that resonate with your objectives, driving transformative success. Our portfolio is a finely-tuned blend of innovation and strategy, designed to amplify your competitive edge.
# Transforming the user experience and boosting profitability with new website.
# Helping researchers combat the global opioid addiction crisis.
# Empowering the local creative scene with a mobile app.
# Redesigning a website to promote financial literacy for future generations.
# Shifting perceptions about the economic vitality of Detroit.
# Enhancing the experience, accessibility, and security for Credit Union members.
# Mitsubishi Electric, a global leader in electric and electronic equipment, has ventured into revolutionizing the drone delivery landscape with its new product offering, Anymile.io.
# Opening new markets, reducing time-to-value, and improving customer satisfaction with a low-code/no-code integration application
# Enabling the successful acquisition of a healthcare solutions provider through cloud migration, application modernization, and robotic process automation
# Reconcepting the user interface and providing an improved user experience to enhance workout success for exercisers.
# Creating an award-winning boat builder that seamlessly integrate product information, pricing, and visuals resulting in 3x lead increase.
# Helping a tier 1 supplier showcase their innovative spirit & capture the attention of the automotive industry.
# Transforming the insurance industry by streamlining the quoting process with AI, leading to increased value and convenience for customers.
# We deliver solutions to:
# Patricia Campbell, Chief Operating Officer.
# Christian Financial Credit Union
# "The Symphonize team is amazing! Their ideas and designs for our website are truly exceptional, and they consistently follow through on delivery. With their flexible, collaborative approach, they are a pleasure to work with, and we just love the end result."
# Sean Johnston, Senior Vice President - Operations and Technology.
# Huntington National Bank
# "The Symphonize team makes it so much easier! They can see through the complexity and the outliers to pull together an elegant solution that makes a complex product more intuitive. The team is always great to work with, challenging us when needed and helping us see beyond our requirements. We’ve been thrilled with the results so far and look forward to what the future will bring."
# Ed Rose, CEO.
# Paqqets
# "Symphonize brings the expertise we need to make good decisions and stay calibrated. Our teams work together seamlessly. If you sat in on a working session, it would be hard to tell the Symphonize folks from my team. They have a seat at the table for every important decision."
# David Jones, CIO.
# Meridian Medical Management
# "Symphonize is a one-stop shop that supports us at every stage: from whiteboarding to architecture to development to implementation. They know what the market is doing and reliably guide us to next generation technologies that will put us ahead of our competition."
# Fady Zoweil, VP of Professional Services.
# Thales Group
# "The Symphonize Solution Architects and development team are excellent. We can assign tough tasks and know they will do them right without creating complexity or delays. I trust Symphonize to deliver on our commitment and achieve our customer’s goals because they've been doing it for 8 years now."
# Terry Leahy, CEO.
# Meridian Medical Management
# "We have been successfully partnering with Symphonize for many years on a broad variety of technologies and product roadmaps. From Big Data analytics product development to rapid development and deployment of RPA,
# Symphonize has been our key strategic relationship.
# Their team functions seamlessly as an extension of our product management teams, which has enabled us to dramatically increase release velocity and quality simultaneously."
# Our unified teams harmonise design thinking and technical excellence to chart new digital experiences.
# Let us orchestrate your digital transformation with unmatched expertise and integrity.
# BOOK A FREE CONSULT
# Connect with us
# California
# 920 Reserve Dr
# Ste 100
# Roseville, CA 95678
# Michigan
# 3051 Miller Rd
# Ann Arbor, MI 48103
# Bengaluru
# Beech E-1, Manyata
# Embassy Business Park
# Ground Floor
# Outer Ring Road, Nagawara
# KA - 560045
# Hyderabad
# 3rd Floor, Plot No. 14/2
# Sector-1, HUDA Techno
# Enclave, Madhapur
# TS - 500081
# Vijayawada
# 3rd Floor
# Sai Odessey Complex
# NH16 Service Road
# Gurunanak Colony
# AP - 520008
# ©
# Symphonize, Inc. All rights reserved.
# | Privacy Policy
# ©
# Symphonize, Inc. All rights reserved.
# | Privacy Policy
# © 2016-2023 Symphonize, Inc. All rights reserved. | Privacy Policy.
#
#
#
# insights page
# Webpage Title:
# Insights | Symphonize
# Webpage Contents:
# About Us
# Services
# Case Studies
# Insights
# Careers
# Contact
# Contact
# Insights
# Stay in tune with Symphonize
# The latest updates, thought leadership, educational videos, and webinars to keep you in sync with the evolving world of technology and innovation.
# All Insights
# Banking
# Legacy Modernization
# Video Testimonials
# Technology
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Watch Now
# Watch Now
# Watch Now
# Watch Now
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# Learn More
# We deliver solutions to:
# Patricia Campbell, Chief Operating Officer.
# Christian Financial Credit Union
# "The Symphonize team is amazing! Their ideas and designs for our website are truly exceptional, and they consistently follow through on delivery. With their flexible, collaborative approach, they are a pleasure to work with, and we just love the end result."
# Sean Johnston, Senior Vice President - Operations and Technology.
# Huntington National Bank
# "The Symphonize team makes it so much easier! They can see through the complexity and the outliers to pull together an elegant solution that makes a complex product more intuitive. The team is always great to work with, challenging us when needed and helping us see beyond our requirements. We’ve been thrilled with the results so far and look forward to what the future will bring."
# Ed Rose, CEO.
# Paqqets
# "Symphonize brings the expertise we need to make good decisions and stay calibrated. Our teams work together seamlessly. If you sat in on a working session, it would be hard to tell the Symphonize folks from my team. They have a seat at the table for every important decision."
# David Jones, CIO.
# Meridian Medical Management
# "Symphonize is a one-stop shop that supports us at every stage: from whiteboarding to architecture to development to implementation. They know what the market is doing and reliably guide us to next generation technologies that will put us ahead of our competition."
# Fady Zoweil, VP of Professional Services.
# Thales Group
# "The Symphonize Solution Architects and development team are excellent. We can assign tough tasks and know they will do them right without creating complexity or delays. I trust Symphonize to deliver on our commitment and achieve our customer’s goals because they've been doing it for 8 years now."
# Terry Leahy, CEO.
# Meridian Medical Management
# "We have been successfully partnering with Symphonize for many years on a broad variety of technologies and product roadmaps. From Big Data analytics product development to rapid development and deployment of RPA,
# Symphonize has been our key strategic relationship.
# Their team functions seamlessly as an extension of our product management teams, which has enabled us to dramatically increase release velocity and quality simultaneously."
# Our unified teams harmonise design thinking and technical excellence to chart new digital experiences.
# Let us orchestrate your digital transformation with unmatched expertise and integrity.
# BOOK A FREE CONSULT
# Connect with us
# California
# 920 Reserve Dr
# Ste 100
# Roseville, CA 95678
# Michigan
# 3051 Miller Rd
# Ann Arbor, MI 48103
# Bengaluru
# Beech E-1, Manyata
# Embassy Business Park
# Ground Floor
# Outer Ring Road, Nagawara
# KA - 560045
# Hyderabad
# 3rd Floor, Plot No. 14/2
# Sector-1, HUDA Techno
# Enclave, Madhapur
# TS - 500081
# Vijayawada
# 3rd Floor
# Sai Odessey Complex
# NH16 Service Road
# Gurunanak Colony
# AP - 520008
# ©
# Symphonize, Inc. All rights reserved.
# | Privacy Policy
# ©
# Symphonize, Inc. All rights reserved.
# | Privacy Policy
# © 2016-2023 Symphonize, Inc. All rights reserved. | Privacy Policy.
#
#
#
# company page
# Webpage Title:
# Symphonize | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Symphonize
# IT Services and IT Consulting
# Roseville, California
# 1,576 followers
# Amplify your digital transformation.
# Follow
# Discover all 132 employees
# Report this company
# About us
# Our unified teams harmonize design thinking and technical excellence to chart new digital experiences. Let us orchestrate your digital transformation with unmatched expertise and integrity.
# Website
# http://www.symphonize.com
# External link for Symphonize
# Industry
# IT Services and IT Consulting
# Company size
# 51-200 employees
# Headquarters
# Roseville, California
# Type
# Privately Held
# Founded
# 2012
# Specialties
# Application Development, Technology Consulting, Systems Integration, Cloud Services, Application Integration, Web Portals, Software Development, Software Product Development, Cloud Services Provider, Robotic Process Automation, and Legacy Application Modernization
# Locations
# Primary
# 920 Reserve Dr
# 100
# Roseville, California 95678, US
# Get directions
# 3rd Floor, Sai Odyssey Complex
# NH16 Service Road, Guru Nanak Colony
# Vijayawada, Andhra Pradesh 520007, IN
# Get directions
# 3rd Floor, Dwaraka Park View, Plot No. 14/2,  Sector-1, HUDA Techno Enclave, Madhapur
# Hyderabad, Telangana 500081, IN
# Get directions
# Beech E-1, Manyata Embassy Business Park
# Outer Ring Road, Nagawara
# Bengaluru, Bangalore 560045, IN
# Get directions
# Employees at Symphonize
# Ray Sewell
# Solution Architect
# Adam Carbone
# Tech Strategist | Bridging Innovation & Business Vision | Championing Digital Transformation & Product Optimization
# Sreedhar Tatavarthi
# Helping Banks Engage Gen Z | Educator | Co-Founder
# Kyle Feliks
# UI/UX Designer
# See all employees
# Updates
# Symphonize
# 1,576 followers
# 1w
# Report this post
# 🎆New Year, New Adventures! ✨
#
# Wishing you a year filled with joy, success, and unforgettable moments. Here’s to 2025—let’s make it amazing! 🥂
# 11
# Like
# Comment
# Share
# Symphonize
# 1,576 followers
# 2w
# Report this post
# 🎄✨ Thankful. Grateful. Merry. ✨🎄
#
# To our clients, partners, and team—thank you for being part of our story.
# Wishing you a joyful
# #Christmas
# 17
# Like
# Comment
# Share
# Symphonize
# 1,576 followers
# 2w
# Report this post
# 🎉 Congratulations to the
# MDT
# team on the successful launch of the MDT Compass App!
#
# We at Symphonize had the privilege of designing and developing💻 the MDT Compass App in close collaboration with the talented MDT team.
#
# This cloud-first solution transforms ✅ how credit unions access critical tools and information - offering secure, real-time, and mobile-friendly capabilities that enhance efficiency and empower seamless communication.
#
# A special thanks 🙏 to
# Jennifer Lee
# , VP of Software & Data Services for MDT, and the entire MDT team for their leadership and commitment to innovation.
#
# We’re proud😊 to be part of this journey and contribute to solutions that drive digital transformation for credit unions.
#
# Check out the full details here👇
# https://lnkd.in/gypnd_aB
# #Innovation
# #CreditUnions
# #CloudFirst
# #MDTCompassApp
# MDT Launches MDT Compass App for Credit Union Community
# businesswire.com
# 18
# 2 Comments
# Like
# Comment
# Share
# Symphonize
# 1,576 followers
# 3w
# Report this post
# 🚀 We’re Proud to Announce Our ISO 9001 Certification! 🚀
#
# This achievement highlights our dedication to quality management and delivering exceptional results every time.
#
# What does it mean for you?
#
# ✅ Consistent, high-quality solutions
# ✅ Continuous improvement in every project
# #ISO9001
# #QualityManagement
# #Excellence
# #Teamwork
# #Innovation
# #CustomerSuccess
# #ContinuousImprovement
# 9
# 1 Comment
# Like
# Comment
# Share
# Symphonize
# 1,576 followers
# 3w
# Report this post
# Is your bank ready to meet the expectations of Gen Z?
#
# As Gen Z becomes a key demographic in the financial sector, community banks need to adapt to their unique needs.
#
# From mobile-first experiences to personalized solutions and sustainability, understanding this generation is crucial for staying competitive.
# Meeting Gen Z’s Needs, A Fresh Approach for Community Banks
# Symphonize on LinkedIn
# 7
# Like
# Comment
# Share
# Symphonize
# 1,576 followers
# 1mo
# Report this post
# 🚀 We’ve Reached CMMI Level 3 Certification! 🚀
#
# This milestone reflects our commitment to delivering high-quality, efficient, and consistent solutions.
#
# What does it mean for you?
#
# ✅ Faster, smoother project delivery
# ✅ Higher quality and predictability
#
# Thanks to our incredible team and valued clients for making this possible! 🌟
# #CMMI
# #Level3
# #Excellence
# #Software
# #Innovation
# #Quality
# #ProcessMaturity
# 22
# Like
# Comment
# Share
# Symphonize
# 1,576 followers
# 1mo
# Report this post
# 🥧💡 Thankful. Grateful. Inspired. 💡🥧
#
# To our clients, partners, and team—you’re the secret sauce to everything we do. Thank you for being part of our story.
#
# Have a
# #Thanksgiving
# as amazing as you are!
# 25
# Like
# Comment
# Share
# Symphonize
# 1,576 followers
# 1mo
# Report this post
# Building trust in the digital age is no small feat! 🌟
#
# At Symphonize, we’re thrilled to partner with forward-thinking leaders like Joanne Rau, CEO of Chelsea State Bank, to craft digital experiences that showcase the perfect blend of tradition and innovation. 🏦✨
# 11
# Like
# Comment
# Share
# Symphonize
# 1,576 followers
# 2mo
# Report this post
# How is your bank connecting with Gen Z—today's digitally savvy, community-focused generation?
#
# In Part 5 of our Power of Personalization series, we share the top strategies for making a real impact with Gen Z customers.
# #GenZ
# #banking
# #symphonize
# #personalization
# #community
# 10 Key Gen Z Marketing Strategies for Banking Institutions
# Symphonize on LinkedIn
# 6
# Like
# Comment
# Share
# Symphonize
# 1,576 followers
# 2mo
# Report this post
# What strategies are you implementing to deepen your understanding of customer needs and foster their loyalty?
#
# This week, we dive into the Power of Personalization in Banking—uncovering actionable tactics that turn data into meaningful customer experiences!
# #banking
# #symphonize
# #usa
# #personalization
# #communitybank
# #creditunion
# #strategy
# #fintech
# Personalization Strategies for Financial Institutions
# Symphonize on LinkedIn
# 12
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Symphonize
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# TekWorks
# Human Resources Services
# Hyderabad, Telangana
# bitLabs
# Education Administration Programs
# Hyderabad, Telangana
# SYMPHONIZE ENTERPRISE SOLUTIONS PRIVATE LIMITED
# VIJAYAWADA, Andhra Pradesh
# Tekworks
# IT Services and IT Consulting
# Poway, CA
# JKS Soft Tech
# Information Technology & Services
# Lakshya Software Technologies Pvt. Ltd.
# IT Services and IT Consulting
# Hyderabad, Telangana
# EDIO
# Data Infrastructure and Analytics
# Hyderabad, Telangana
# GoogleSoS IT
# IT Services and IT Consulting
# Vijayawada, Andhra Pradesh
# Symphonize
# Technology, Information and Internet
# Suthra Technologies
# IT Services and IT Consulting
# Voorhees, New Jersey
# Show more similar pages
# Show fewer similar pages
# More searches
# More searches
# Vice President jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Symphonize
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# careers page
# Webpage Title:
# Careers | Symphonize
# Webpage Contents:
# About Us
# Services
# Case Studies
# Insights
# Careers
# Contact
# Contact
# Careers
# Elevate your career with Symphonize:
# At Symphonize, we’re not just building a company; we’re creating a movement. Our dedication to every client’s success, and our unwavering commitment to trust and personal responsibility in all our relationships, set us apart. If you’re passionate about making a meaningful impact while sharing our values, explore career opportunities at Symphonize today.
# Current Open Positions
# Solution Architect
# View Position
# Senior Java Backend Developer
# View Position
# Jr. Javascript Node Developer
# View Position
# Ann Arbor
# Michigan
# Vijayawada
# India
# We deliver solutions to:
# Patricia Campbell, Chief Operating Officer.
# Christian Financial Credit Union
# "The Symphonize team is amazing! Their ideas and designs for our website are truly exceptional, and they consistently follow through on delivery. With their flexible, collaborative approach, they are a pleasure to work with, and we just love the end result."
# Sean Johnston, Senior Vice President - Operations and Technology.
# Huntington National Bank
# "The Symphonize team makes it so much easier! They can see through the complexity and the outliers to pull together an elegant solution that makes a complex product more intuitive. The team is always great to work with, challenging us when needed and helping us see beyond our requirements. We’ve been thrilled with the results so far and look forward to what the future will bring."
# Ed Rose, CEO.
# Paqqets
# "Symphonize brings the expertise we need to make good decisions and stay calibrated. Our teams work together seamlessly. If you sat in on a working session, it would be hard to tell the Symphonize folks from my team. They have a seat at the table for every important decision."
# David Jones, CIO.
# Meridian Medical Management
# "Symphonize is a one-stop shop that supports us at every stage: from whiteboarding to architecture to development to implementation. They know what the market is doing and reliably guide us to next generation technologies that will put us ahead of our competition."
# Fady Zoweil, VP of Professional Services.
# Thales Group
# "The Symphonize Solution Architects and development team are excellent. We can assign tough tasks and know they will do them right without creating complexity or delays. I trust Symphonize to deliver on our commitment and achieve our customer’s goals because they've been doing it for 8 years now."
# Terry Leahy, CEO.
# Meridian Medical Management
# "We have been successfully partnering with Symphonize for many years on a broad variety of technologies and product roadmaps. From Big Data analytics product development to rapid development and deployment of RPA,
# Symphonize has been our key strategic relationship.
# Their team functions seamlessly as an extension of our product management teams, which has enabled us to dramatically increase release velocity and quality simultaneously."
# Our unified teams harmonise design thinking and technical excellence to chart new digital experiences.
# Let us orchestrate your digital transformation with unmatched expertise and integrity.
# BOOK A FREE CONSULT
# Connect with us
# California
# 920 Reserve Dr
# Ste 100
# Roseville, CA 95678
# Michigan
# 3051 Miller Rd
# Ann Arbor, MI 48103
# Bengaluru
# Beech E-1, Manyata
# Embassy Business Park
# Ground Floor
# Outer Ring Road, Nagawara
# KA - 560045
# Hyderabad
# 3rd Floor, Plot No. 14/2
# Sector-1, HUDA Techno
# Enclave, Madhapur
# TS - 500081
# Vijayawada
# 3rd Floor
# Sai Odessey Complex
# NH16 Service Road
# Gurunanak Colony
# AP - 520008
# ©
# Symphonize, Inc. All rights reserved.
# | Privacy Policy
# ©
# Symphonize, Inc. All rights reserved.
# | Privacy Policy
# © 2016-2023 Symphonize, Inc. All rights reserved. | Privacy Policy.

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
import requests

def validate_url(url):
    if not url.startswith(("http://", "https://")):
        url = "https://" + url
    return url

def get_all_details(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx and 5xx)
        return response.text  # Assuming you want the raw HTML content
    except requests.exceptions.RequestException as e:
        print(f"Error fetching details from URL: {e}")
        return "Error fetching content. Please check the URL."

def get_brochure_user_prompt(company_name, url):
    url = validate_url(url)  # Ensure the URL is valid
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    details = get_all_details(url)
    user_prompt += details[:5_000]  # Truncate if more than 5,000 characters
    return user_prompt

# %%
print(get_brochure_user_prompt("Symphonize", "https://www.symphonize.com/"))
# Out:
# You are looking at a company called: Symphonize
# Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.
# <!DOCTYPE html><!-- This site was created in Webflow. https://webflow.com --><!-- Last Published: Thu Dec 19 2024 15:27:44 GMT+0000 (Coordinated Universal Time) --><html data-wf-domain="www.symphonize.com" data-wf-page="65e7140156ebb28e19473bf7" data-wf-site="634690d9583ce36a5e30c703"><head><meta charset="utf-8"/><title>Symphonize | Amplify your digital transformation.</title><meta content="Our team of experts in UX, Engineering, and Delivery collaborates seamlessly to craft innovative solutions that maximize results." name="description"/><meta content="Symphonize | Amplify your digital transformation." property="og:title"/><meta content="Our team of experts in UX, Engineering, and Delivery collaborates seamlessly to craft innovative solutions that maximize results." property="og:description"/><meta content="Symphonize | Amplify your digital transformation." property="twitter:title"/><meta content="Our team of experts in UX, Engineering, and Delivery collaborates seamlessly to craft innovative solutions that maximize results." property="twitter:description"/><meta property="og:type" content="website"/><meta content="summary_large_image" name="twitter:card"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="Webflow" name="generator"/><link href="https://cdn.prod.website-files.com/634690d9583ce36a5e30c703/css/symphonize.webflow.4b0a7bd13.min.css" rel="stylesheet" type="text/css"/><link href="https://fonts.googleapis.com" rel="preconnect"/><link href="https://fonts.gstatic.com" rel="preconnect" crossorigin="anonymous"/><script src="https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script><script type="text/javascript">WebFont.load({  google: {    families: ["Ubuntu:300,300italic,400,400italic,500,500italic,700,700italic","Open Sans:300,300italic,400,400italic,600,600italic,700,700italic,800,800italic","Oswald:200,300,400,500,600,700","Montserrat:100,100italic,200,200italic,300,300italic,400,400italic,500,500italic,600,600italic,700,700italic,800,800italic,900,900italic","Inconsolata:400,700","Inter:100,200,300,regular,500,600,700,800,900","League Spartan:100,200,300,regular,500,600,700,800,900","Inter:regular,800,900"]  }});</script><script type="text/javascript">!function(o,c){var n=c.documentElement,t=" w-mod-";n.className+=t+"js",("ontouchstart"in o||o.DocumentTouch&&c instanceof DocumentTouch)&&(n.className+=t+"touch")}(window,document);</script><link href="https://cdn.prod.website-files.com/634690d9583ce36a5e30c703/634d96880253ff16b14f53e5_favicon-32x32.png" rel="shortcut icon" type="image/x-icon"/><link href="https://cdn.prod.website-files.com/634690d9583ce36a5e30c703/65f284da70e70f29d2210f23_FavIcon.png" rel="apple-touch-icon"/><style>
# .w-slider-dot {
#  background: #007CEF !important;
#  border-radius: 30px 30px 30px 30px;
# }
# .w-slider-dot.w-active {
#  background: #007CEF !important;
#  width: 80px;
#  height: 10px;
#  border-radius: 30px 30px 30px 30px;
# }
# </style></head><body><div data-animation="default" data-collapse="medium" data-duration="400" data-easing="ease" data-easing2="ease" role="banner" class="common-navbar dark-mode dark-bg w-nav"><div class="nav-common-container w-container"><div class="common-nav-div"><a href="/" aria-current="page" class="symphonize-brand w-nav-brand w--current"><img src="https://cdn.prod.website-files.com/634690d9583ce36a5e30c703/65701df905012326402f8256_White-Logo.png" loading="lazy" alt="" class="image-99"/></a><nav role="navigation" class="nav-menu-4 w-nav-menu"><a href="/about" class="common-nav-link dark-mode w-nav-link">About Us</a><a href="/services" class="common-nav-link dark-mode w-nav-link">Services</a><a href="https://www.symphonize.com/case-studies" class="common-nav-link dark-mode">Case Studies</a><a href="/insights" class="common-nav-link dark-mode w-nav-link">Insights</a><a href="/careers" class="common-nav-link dark-mode w-nav-link">Careers</a><a href="/contact-us" class="common-nav-link dark-mode hide w-nav-link">Contact</a><a href="/contact-us" class="button-link w-inline-block"><div class="button-text">Contact</div><div class="dot-link-div"><div class="button-line"></div><div class="button-dot"></div></div><div class="button-outline"></div></a></nav><div class="menu-button-5 w-nav-button"><div class="icon-23 w-icon-nav-menu"></div></div></div></div></div><section id="top-hero-section" class="main-hero-page-section"><div class="w-layout-blockcontainer main-common-container home-page w-container"><h1 class="main-common-heading white-text center">Amplify your digital transformation.</h1><div class="common-sub-text dark-mode center">Our team of experts in UX, Engineering, and Delivery collaborates seamlessly to craft innovative solutions that maximize results.</div></div><div class="hero-lottie-animation-div"><div class="hero-double-waves-lottie-animation" data-w-id="cfba48d9-2c75-b594-6825-b8df36d91aca" data-animation-type="lottie" data-src="https://cdn.prod.website-files.com/634690d9583ce

# %%
def create_brochure(company_name, url):
    response = ollama_via_openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("Symphonize", "https://www.symphonize.com/")
# Out:
# **Symphonize Brochure**
# ======================
#
# [Cover Image: Symphonyze Logo](https://cdn.prod.website-files.com/634690d9583ce36a5e30c703/65701df905012326402f8256_White-Logo.png)
#
# Welcome to SymphoniZe
# ---------------------
#
# Amplify your digital transformation with our team of experts in UX, Engineering, and Delivery. We craft innovative solutions that maximize results.
#
# **Our Story**
# -------------
#
# At SymphoniZe, we believe that technology should enhance human experience, not control it. Our team of experts comes together from diverse backgrounds to deliver cutting-edge solutions that meet the unique needs of our clients.
#
# **Services**
# ----------
#
# * UX Design
# * Engineering
# * Delivery
#
# **What We Do Best**
# -------------------
#
# We help organizations transform their digital presence with innovative solutions that:
#
# * Enhance user experience
# * Drive business growth
# * Deliver exceptional results
#
# **Case Studies**
# --------------
#
# Read about the success stories of our clients who have trusted us to deliver high-quality solutions.
#
# [Link to Case Studies Page](https://www.symphonize.com/case-studies)
#
# **Insights & Expertise**
# -----------------------
#
# Stay ahead of the curve with our thought leadership articles, insights, and expert advice on the latest trends in digital transformation.
#
# [Link to Insights Page](https://www.symphonize.com/insights)
#
# **Careers & Join Us**
# ---------------------
#
# Join our team of innovators and help shape the future of digital transformation. We offer exciting opportunities for talented individuals to grow with us.
#
# [Link to Careers Page](https://www.symphonize.com/careers)
#
# **Stay Connected**
# -----------------
#
# Follow us on social media to stay up-to-date with the latest news, trends, and insights from SymphoniZe.
#
# * LinkedIn: [LinkedIn Link]
# * Twitter: [Twitter Link]
# * Facebook: [Facebook Link]
#
# Contact Us
# ----------
#
# Get in touch with our team today to learn more about how we can help you amplify your digital transformation.
#
# [Link to Contact Us Page](https://www.symphonize.com/contact-us)

# %%
def stream_brochure(company_name, url):
    stream = ollama_via_openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
        ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        
        # Add colors using HTML and emojis
        response = response.replace("```", "").replace("markdown", "")
        response = response.replace(
            "Company Highlights", 
            '<span style="color:blue;">Company Highlights 🌟</span>'
        )
        
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("Symphonize", "https://www.symphonize.com/")
# Out:
# **Symphonize Brochure**
# =========================
#
# **Overview**
# ------------
#
# Symphonize is a leading digital transformation solutions provider that helps organizations amplify their business potential. With a team of experts in UX, Engineering, and Delivery, we collaborate seamlessly to craft innovative solutions that maximize results.
#
# **Our Philosophy**
# -----------------
#
# At Symphonize, we believe that digital transformation is not just about technology, but about people and culture too. We're committed to creating solutions that are both effective and engaging, because we know that's what makes all the difference for our clients.
#
# **Our Clients**
# --------------
#
# We've had the privilege of working with some amazing organizations across various industries. Our clients trust us to deliver innovative solutions that drive real results.
#
# * [Your Company Name], a leading [industry] player
# * [Another Client's Name], a pioneering brand in [industry]
# * [Third Client's Name], a innovative start-up
#
# **Our Services**
# -----------------
#
# We offer a range of digital transformation services, including:
#
# * UX design and consulting
# * Engineering and development
# * Delivery and implementation
#
# **Why Choose Symphonize?**
# -------------------------
#
# * Expertise: Our team has years of experience in delivering successful digital projects.
# * Collaboration: We believe that collaboration is key to success. That's why we work closely with our clients to understand their needs and deliver solutions that meet their goals.
# * Innovation: We're always looking for new ways to solve problems and innovate our services.
#
# **Join Our Team**
# ---------------
#
# If you're passionate about digital transformation and want to be part of a talented team, check out our careers page for current openings. [link]
#
# **Contact Us**
# --------------
#
# Ready to discuss how we can help your organization amplify its digital transformation? Contact us today! [link]
